# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
kashti=sns.load_dataset("titanic")
ks1=kashti
ks2=kashti

# %%
ks1
# Out:
#      survived  pclass     sex  age in days  sibsp  parch     fare embarked  \
# 1         1.0       1  female      13870.0      1      0  71.2833        C
# 3         1.0       1  female      12775.0      1      0  53.1000        S
# 6         0.0       1    male      19710.0      0      0  51.8625        S
# 10        1.0       3  female       1460.0      1      1  16.7000        S
# 11        1.0       1  female      21170.0      0      0  26.5500        S
# ..        ...     ...     ...          ...    ...    ...      ...      ...
# 871       1.0       1  female      17155.0      1      1  52.5542        S
# 872       0.0       1    male      12045.0      0      0   5.0000        S
# 879       1.0       1  female      20440.0      0      1  83.1583        C
# 887       1.0       1  female       6935.0      0      0  30.0000        S
# 889       1.0       1    male       9490.0      0      0  30.0000        C
#
#      class    who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
(kashti["age"]+12).head(10)
# Out:
# 1     50.000000
# 3     47.000000
# 6     66.000000
# 10    16.000000
# 11    70.000000
# 21    46.000000
# 23    40.000000
# 27    31.000000
# 31    47.623187
# 52    61.000000
# Name: age, dtype: float64

# %%
kashti.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
kashti.dropna(subset=["deck"], axis=0, inplace=True)

# %%
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti.shape
# Out:
# (203, 15)

# %%
kashti.isnull().sum()
# Out:
# survived        0
# pclass          0
# sex             0
# age            19
# sibsp           0
# parch           0
# fare            0
# embarked        2
# class           0
# who             0
# adult_male      0
# deck            0
# embark_town     2
# alive           0
# alone           0
# dtype: int64

# %%
ks1=ks1.dropna()
ks1
# Out:
#      survived  pclass     sex  age in days  sibsp  parch     fare embarked  \
# 1         1.0       1  female      13870.0      1      0  71.2833        C
# 3         1.0       1  female      12775.0      1      0  53.1000        S
# 6         0.0       1    male      19710.0      0      0  51.8625        S
# 10        1.0       3  female       1460.0      1      1  16.7000        S
# 11        1.0       1  female      21170.0      0      0  26.5500        S
# ..        ...     ...     ...          ...    ...    ...      ...      ...
# 871       1.0       1  female      17155.0      1      1  52.5542        S
# 872       0.0       1    male      12045.0      0      0   5.0000        S
# 879       1.0       1  female      20440.0      0      1  83.1583        C
# 887       1.0       1  female       6935.0      0      0  30.0000        S
# 889       1.0       1    male       9490.0      0      0  30.0000        C
#
#      class    who  adult_male deck  embark_town alive  alone
# ...

# %%
ks1.shape
# Out:
# (182, 15)

# %%
mean=ks1["age"].mean()
mean
# Out:
# 35.62318681318681

# %%
ks2["age"]=ks2["age"].replace(np.nan, mean)
ks2["age"]
# Out:
# 1      38.0
# 3      35.0
# 6      54.0
# 10      4.0
# 11     58.0
#        ...
# 871    47.0
# 872    33.0
# 879    56.0
# 887    19.0
# 889    26.0
# Name: age, Length: 203, dtype: float64

# %%
ks2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
ks1.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
ks1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# Data formatting

# %%
ks1.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
ks1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
ks1["survived"]=ks1["survived"].astype("float64")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1780\3493490888.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks1["survived"]=ks1["survived"].astype("float64")

# %%
ks1.dtypes
# Out:
# survived        float64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
ks1["age"]=ks1["age"]*365
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1780\3277037071.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks1["age"]=ks1["age"]*365

# %%
ks1.head()
# Out:
#     survived  pclass     sex      age  sibsp  parch     fare embarked  class  \
# 1        1.0       1  female  13870.0      1      0  71.2833        C  First
# 3        1.0       1  female  12775.0      1      0  53.1000        S  First
# 6        0.0       1    male  19710.0      0      0  51.8625        S  First
# 10       1.0       3  female   1460.0      1      1  16.7000        S  Third
# 11       1.0       1  female  21170.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True

# %%
ks1.rename(columns={"age":"age in days"},inplace=True)
ks1.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1780\1043040819.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks1.rename(columns={"age":"age in days"},inplace=True)
#     survived  pclass     sex  age in days  sibsp  parch     fare embarked  \
# 1        1.0       1  female      13870.0      1      0  71.2833        C
# 3        1.0       1  female      12775.0      1      0  53.1000        S
# 6        0.0       1    male      19710.0      0      0  51.8625        S
# 10       1.0       3  female       1460.0      1      1  16.7000        S
# 11       1.0       1  female      21170.0      0      0  26.5500        S
#
#     class    who  adult_male deck  embark_town alive  alone
# 1   First  woman       False    C    Cherbourg   yes  False
# ...

# %% [markdown]
# Data normalization

# %%
ks4=ks1[["age in days","fare"]]

# %%
ks4
# Out:
#      age in days     fare
# 1        13870.0  71.2833
# 3        12775.0  53.1000
# 6        19710.0  51.8625
# 10        1460.0  16.7000
# 11       21170.0  26.5500
# ..           ...      ...
# 871      17155.0  52.5542
# 872      12045.0   5.0000
# 879      20440.0  83.1583
# 887       6935.0  30.0000
# 889       9490.0  30.0000
#
# [182 rows x 2 columns]

# %%
ks4["fare"]=ks4["fare"]/ks4["fare"].max()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1780\2897205287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks4["fare"]=ks4["fare"]/ks4["fare"].max()

# %%
ks4.head()
# Out:
#     age in days      fare
# 1       13870.0  0.139136
# 3       12775.0  0.103644
# 6       19710.0  0.101229
# 10       1460.0  0.032596
# 11      21170.0  0.051822

# %%
ks4
# Out:
#      age in days      fare
# 1        13870.0  0.139136
# 3        12775.0  0.103644
# 6        19710.0  0.101229
# 10        1460.0  0.032596
# 11       21170.0  0.051822
# ..           ...       ...
# 871      17155.0  0.102579
# 872      12045.0  0.009759
# 879      20440.0  0.162314
# 887       6935.0  0.058556
# 889       9490.0  0.058556
#
# [182 rows x 2 columns]

# %%
ks4["fare"]=(ks4["fare"]-ks4["fare"].min())/(ks4["fare"].max()-ks4["fare"].min())
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1780\1580312675.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks4["fare"]=(ks4["fare"]-ks4["fare"].min())/(ks4["fare"].max()-ks4["fare"].min())

# %%
ks4
# Out:
#      age in days      fare
# 1        13870.0  0.139136
# 3        12775.0  0.103644
# 6        19710.0  0.101229
# 10        1460.0  0.032596
# 11       21170.0  0.051822
# ..           ...       ...
# 871      17155.0  0.102579
# 872      12045.0  0.009759
# 879      20440.0  0.162314
# 887       6935.0  0.058556
# 889       9490.0  0.058556
#
# [182 rows x 2 columns]

# %%
ks4["fare"]=(ks4["fare"]-ks4["fare"].mean())/ks4["fare"].std()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1780\2670180047.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks4["fare"]=(ks4["fare"]-ks4["fare"].mean())/ks4["fare"].std()

# %%
ks4
# Out:
#      age in days      fare
# 1        13870.0 -0.099835
# 3        12775.0 -0.337554
# 6        19710.0 -0.353732
# 10        1460.0 -0.813428
# 11       21170.0 -0.684654
# ..           ...       ...
# 871      17155.0 -0.344689
# 872      12045.0 -0.966388
# 879      20440.0  0.055413
# 887       6935.0 -0.639551
# 889       9490.0 -0.639551
#
# [182 rows x 2 columns]

# %%
ks6=sns.load_dataset("titanic")

# %%
ks6
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# Log_transformation

# %%
ks6["fare"]=np.log(ks6["fare"])
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
ks6
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0  1.981001        S   Third
# 1           1       1  female  38.0      1      0  4.266662        C   First
# 2           1       3  female  26.0      0      0  2.070022        S   Third
# 3           1       1  female  35.0      1      0  3.972177        S   First
# 4           0       3    male  35.0      0      0  2.085672        S   Third
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 886         0       2    male  27.0      0      0  2.564949        S  Second
# 887         1       1  female  19.0      0      0  3.401197        S   First
# 888         0       3  female   NaN      1      2  3.154870        S   Third
# 889         1       1    male  26.0      0      0  3.401197        C   First
# 890         0       3    male  32.0      0      0  2.047693        Q   Third
#
# ...

# %%
bins=np.linspace(min(ks6["age"]), max(ks6["age"]),15000)
age_groups=["bachay","jawan","boorhey"]
ks6["age"]=pd.cut(ks6["age"], bins, labels=age_groups, include_lowest=True)
ks6["age"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Admin\Documents\Drive D\Videos (01.08.2022)\Python\Python_work\Pandas\Data wrangling.ipynb Cell 47 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/Documents/Drive%20D/Videos%20%2801.08.2022%29/Python/Python_work/Pandas/Data%20wrangling.ipynb#ch0000044?line=0'>1</a> bins=np.linspace(min(ks6["age"]), max(ks6["age"]),15000)
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/Documents/Drive%20D/Videos%20%2801.08.2022%29/Python/Python_work/Pandas/Data%20wrangling.ipynb#ch0000044?line=1'>2</a> age_groups=["bachay","jawan","boorhey"]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Admin/Documents/Drive%20D/Videos%20%2801.08.2022%29/Python/Python_work/Pandas/Data%20wrangling.ipynb#ch0000044?line=2'>3</a> ks6["age"]=pd.cut(ks6["age"], bins, labels=age_groups, include_lowest=True)
# ...

# %%
ks6
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0  1.981001        S   Third
# 1           1       1  female  38.0      1      0  4.266662        C   First
# 2           1       3  female  26.0      0      0  2.070022        S   Third
# 3           1       1  female  35.0      1      0  3.972177        S   First
# 4           0       3    male  35.0      0      0  2.085672        S   Third
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 886         0       2    male  27.0      0      0  2.564949        S  Second
# 887         1       1  female  19.0      0      0  3.401197        S   First
# 888         0       3  female   NaN      1      2  3.154870        S   Third
# 889         1       1    male  26.0      0      0  3.401197        C   First
# 890         0       3    male  32.0      0      0  2.047693        Q   Third
#
# ...

# %%
pd.get_dummies(ks6["class"])
# Out:
#      First  Second  Third
# 0        0       0      1
# 1        1       0      0
# 2        0       0      1
# 3        1       0      0
# 4        0       0      1
# ..     ...     ...    ...
# 886      0       1      0
# 887      1       0      0
# 888      0       0      1
# 889      1       0      0
# 890      0       0      1
#
# [891 rows x 3 columns]

# %%
pd.get_dummies(ks6["sex"])
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [891 rows x 2 columns]

# %%
ks7=sns.load_dataset("titanic")

# %%
pip install tensorflow
